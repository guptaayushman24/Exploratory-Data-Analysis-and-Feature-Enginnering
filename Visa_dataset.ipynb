# %%
# Importing neccessary libraries for EDA
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Loading the dataset
data = pd.read_csv('Visadataset.csv')

# %%
# Displaying the dataset
data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# Displaying the top 5 rows of the data
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# Displaying the last 5 rows of the data
data.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
# Checking the unique value in the case_status
data.value_counts('case_status')
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (25480, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
data.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
# In the no_of_employees there is negative value which is not possible so we convert all the negative value into the positive value

# %%
def positive (x) :
    if (x<0) :
        return abs(x)
    return x

# %%
data['no_of_employees'] = data['no_of_employees'].apply(positive)

# %%
data[data['no_of_employees']<0]
# Out:
# Empty DataFrame
# Columns: [case_id, continent, education_of_employee, has_job_experience, requires_job_training, no_of_employees, yr_of_estab, region_of_employment, prevailing_wage, unit_of_wage, full_time_position, case_status]
# Index: []

# %%
data.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.089207   1979.409929     74455.814592
# std       22877.917453     42.366929     52815.942327
# min          11.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
data.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
# Case-Id is not an important feature so we will drop it
data.drop('case_id',axis=1,inplace=True)

# %%
data.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status
# 0         Hour                  Y      Denied
# ...

# %% [markdown]
# Seperating the categorical and numerical columns

# %%
lst_cat=[]
lst_num=[]

# %%
for i in data :
    if (data[i].dtype=='O') :
        lst_cat.append(i)
    else :
        lst_num.append(i)

# %%
# Displaying the categorical data
lst_cat
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
# Displaying the numerical data
lst_num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# Checking and handling the missing values

# %%
data.isnull().sum()
# Out:
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Doing the univariate analysis

# %%
for i in lst_num:
    plt.figure(figsize=(8, 6))  # Create a new figure for each plot
    sns.kdeplot(data=data, x=i,shade=True)
    plt.title(f'KDE Plot for {i}')  # Add a title for the plot
    plt.show()
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_9736\621806421.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, x=i,shade=True)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_9736\621806421.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, x=i,shade=True)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_9736\621806421.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, x=i,shade=True)

# %%
data.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.089207   1979.409929     74455.814592
# std       22877.917453     42.366929     52815.942327
# min          11.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %%
for i in lst_num:
    plt.figure(figsize=(8, 6))  # Create a new figure for each plot
    sns.kdeplot(data=data, x=i,shade=True)
    plt.title(f'KDE Plot for {i}')  # Add a title for the plot
    plt.show()
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_9736\621806421.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, x=i,shade=True)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_9736\621806421.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, x=i,shade=True)
# C:\Users\gupta\AppData\Local\Temp\ipykernel_9736\621806421.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=data, x=i,shade=True)

# %% [markdown]
# # Handling and Visualizing the outliers in the dataset

# %% [markdown]
# Visualizing the ouliers using the box plot

# %%
for i in lst_num :
    sns.boxplot(data=data,x=data[i])
    plt.show()

# %%
lst_num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# Creating the function for the outliers
def outliers (df,variable) :
    q3 = df[variable].quantile(0.75)
    q1 = df[variable].quantile(0.25)
    iqr = q3-q1
    lower_range = q1-1.5*iqr
    higher_range = q3+1.5*iqr
    return lower_range,higher_range

# %%
# Checking the outliers in the numerical columns
for i in lst_num :
    l_range,h_range = outliers(data,i)
    print("Outliers in the {} column is from {} to {} ".format(i,l_range,h_range))
# Out:
# Outliers in the no_of_employees column is from -2701.0 to 7227.0
# Outliers in the yr_of_estab column is from 1932.5 to 2048.5
# Outliers in the prevailing_wage column is from -76564.56875000002 to 218315.56125000003

# %%
for i in lst_num :
    feature_name = i

    l_range, h_range = outliers(data, feature_name)

    outliers_df = data[(data[feature_name] < l_range) | (data[feature_name] > h_range)]
    total_outliers = len(outliers_df)

    print("Total number of outliers in the {} feature: {}".format(i, total_outliers))
# Out:
# Total number of outliers in the no_of_employees feature: 1556
# Total number of outliers in the yr_of_estab feature: 3260
# Total number of outliers in the prevailing_wage feature: 427

# %% [markdown]
# Checking the corelation of the feature

# %%
data.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %%
plt.scatter(x=data['yr_of_estab'],y=data['prevailing_wage'])
plt.xlabel("Year of establishment")
plt.ylabel("Prevailing wage")
plt.show()

# %%
plt.scatter(x=data['yr_of_estab'],y=data['no_of_employees'])
plt.xlabel("Year of establishment")
plt.ylabel("Number of employees")
plt.show()

# %% [markdown]
# Categorical Analysis

# %%
data.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status
# 0         Hour                  Y      Denied
# ...

# %%
data.groupby('continent')['no_of_employees'].count()
# Out:
# continent
# Africa             551
# Asia             16861
# Europe            3732
# North America     3292
# Oceania            192
# South America      852
# Name: no_of_employees, dtype: int64

# %%
a = data.groupby('continent')['no_of_employees'].count()
print(len(a))
# Out:
# 6

# %%
employee=[]
i=0
while (i!=6) :
    employee.append(data.groupby('continent')['no_of_employees'].count()[i])
    i=i+1

# %%
employee
# Out:
# [551, 16861, 3732, 3292, 192, 852]

# %%
continent=['Africa','Asia','Europe','North America','Oceania','South America']
employee
plt.bar(continent, employee, color=['red', 'blue', 'green', 'orange'])

plt.ylabel('Number of Employees')
plt.xlabel('Continents')
plt.title('Number of Employees vs Continents')

plt.show()

# %%
data.groupby('education_of_employee')['no_of_employees'].count()
# Out:
# education_of_employee
# Bachelor's     10234
# Doctorate       2192
# High School     3420
# Master's        9634
# Name: no_of_employees, dtype: int64

# %%
emp_number=[]
education_level = ["Bachelor's",'Doctorate','High School', "Master's"]
i=0
while (i!=4) :
    emp_number.append(data.groupby('education_of_employee')['no_of_employees'].count()[i])
    i=i+1
plt.bar(education_level, emp_number, color=['red', 'blue', 'red', 'orange'])

plt.ylabel('Number of employees')
plt.xlabel('Level of education')
plt.title('Numeber of employees vs Level of education')

plt.show()

# %%
data.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status
# 0         Hour                  Y      Denied
# ...

# %%
data.groupby('education_of_employee')['prevailing_wage'].count()
# Out:
# education_of_employee
# Bachelor's     10234
# Doctorate       2192
# High School     3420
# Master's        9634
# Name: prevailing_wage, dtype: int64

# %%
lst_wage=[]
education_level = ["Bachelor's",'Doctorate','High School', "Master's"]
i=0
while (i!=4) :
    lst_wage.append(data.groupby('education_of_employee')['prevailing_wage'].count()[i])
    i=i+1
plt.bar(education_level, lst_wage, color=['red', 'blue', 'red', 'orange'])

plt.ylabel('Wages')
plt.xlabel('Level of education')
plt.title('Wages vs Level of education')

plt.show()

# %%
data.groupby('unit_of_wage')['prevailing_wage'].count()
# Out:
# unit_of_wage
# Hour      2157
# Month       89
# Week       272
# Year     22962
# Name: prevailing_wage, dtype: int64

# %%
len(data.groupby('unit_of_wage')['prevailing_wage'].count())
# Out:
# 4

# %%
wage=[]
unit=['Hour','Month','Week','Year']
i=0
while (i!=4) :
    wage.append(data.groupby('unit_of_wage')['prevailing_wage'].count()[i])
    i=i+1

plt.bar(unit, wage, color=['red', 'blue', 'red', 'orange'])

plt.ylabel('Wages')
plt.xlabel('Unit')
plt.title('Wages vs Unit')

plt.show()

# %%
# Education of employee vs Full_time_position
data.groupby('education_of_employee')['full_time_position'].count()
# Out:
# education_of_employee
# Bachelor's     10234
# Doctorate       2192
# High School     3420
# Master's        9634
# Name: full_time_position, dtype: int64

# %%
full_time_yes = []
i=0
while (i!=8) :
    full_time_yes.append(data.groupby('education_of_employee')['full_time_position'].value_counts()[i])
    i=i+2

# %%
full_time_yes
# Out:
# [9551, 2112, 3214, 7896]

# %%
try :
    full_time_no = []
    i=1
    while (i!=8) :
        full_time_no.append(data.groupby('education_of_employee')['full_time_position'].value_counts()[i])
        i=i+2
except IndexError :
    print("")

# %%
data.groupby('education_of_employee')['full_time_position'].value_counts().unstack(fill_value=0)
# Out:
# full_time_position        N     Y
# education_of_employee
# Bachelor's              683  9551
# Doctorate                80  2112
# High School             206  3214
# Master's               1738  7896

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
education_level = ["Bachelor's",'Doctorate','High School', "Master's"]
full_time_yes
ax.pie(full_time_yes, labels = education_level,autopct='%1.2f%%')
plt.title("Percentage of people who are working as a full time position")
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
education_level = ["Bachelor's",'Doctorate','High School', "Master's"]
full_time_no
ax.pie(full_time_no, labels = education_level,autopct='%1.2f%%')
plt.title("Percentage of people who are not working as a full time position")
plt.show()

# %%
# Also so which continent has the more number of visa certufied and for which denied

# %%
data.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status
# 0         Hour                  Y      Denied
# ...

# %%
data.groupby('continent')['case_status'].value_counts().unstack(fill_value=0)
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
visa_approv = []
i=0
while (i!=12) :
    visa_approv.append(data.groupby('continent')['case_status'].value_counts()[i])
    i+=2

# %%
try :
    visa_not_approv = []
    i=1
    while (i!=12) :
        visa_not_approv.append(data.groupby('continent')['case_status'].value_counts()[i])
        i+=2
except :
    print("")

# %%
visa_approv
# Out:
# [397, 11012, 2957, 2037, 122, 493]

# %%
visa_not_approv
# Out:
# [154, 5849, 775, 1255, 70, 359]

# %%
data.groupby('continent')['case_status'].value_counts()
# Out:
# continent      case_status
# Africa         Certified        397
#                Denied           154
# Asia           Certified      11012
#                Denied          5849
# Europe         Certified       2957
#                Denied           775
# North America  Certified       2037
#                Denied          1255
# Oceania        Certified        122
#                Denied            70
# South America  Certified        493
#                Denied           359
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
continent=['Africa','Asia','Europe','North America','Oceania','South America']
visa_approv
ax.pie(visa_approv, labels = continent,autopct='%1.2f%%')
plt.title("Percentage of different continet who get the visa")
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
continent=['Africa','Asia','Europe','North America','Oceania','South America']
visa_not_approv
ax.pie(visa_not_approv, labels = continent,autopct='%1.2f%%')
plt.title("Percentage of different continet who did not get the visa")
plt.show()

# %%
data.head()
# Out:
#   continent education_of_employee has_job_experience requires_job_training  \
# 0      Asia           High School                  N                     N
# 1      Asia              Master's                  Y                     N
# 2      Asia            Bachelor's                  N                     Y
# 3      Asia            Bachelor's                  N                     N
# 4    Africa              Master's                  Y                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status
# 0         Hour                  Y      Denied
# ...

# %% [markdown]
# Applying one-hot encoding technique in the categorical column

# %%
# Applying the one-hot encoding on the has_job_experience replacing Y with 1 and N with 0
data ['has_job_experience'] = data['has_job_experience'].map({'Y':1,'N':0})

# %%
data.head()
# Out:
#   continent education_of_employee  has_job_experience requires_job_training  \
# 0      Asia           High School                   0                     N
# 1      Asia              Master's                   1                     N
# 2      Asia            Bachelor's                   0                     Y
# 3      Asia            Bachelor's                   0                     N
# 4    Africa              Master's                   1                     N
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage full_time_position case_status
# ...

# %%
# Applying the one-hot encoding on the requires_job_training replacing Y with 1 and N with 0
data ['requires_job_training'] = data['requires_job_training'].map({'Y':1,'N':0})

# %%
# Applying the one-hot encoding on the requires_job_training replacing Y with 1 and N with 0
data ['full_time_position'] = data['full_time_position'].map({'Y':1,'N':0})

# %%
# Applying the one-hot encoding on the continent replacing Asia with 0,Africa  with 1,North America with 2, Europe with 3 , South America with 4 and Oceania with 5
data['continent'] = data['continent'].map({'Asia':0,'Africa':1,'North America':2,'Europe':3,'South America':4,'Oceania':5})

# %%
data.head()
# Out:
#    continent education_of_employee  has_job_experience  requires_job_training  \
# 0          0           High School                   0                      0
# 1          0              Master's                   1                      0
# 2          0            Bachelor's                   0                      1
# 3          0            Bachelor's                   0                      0
# 4          1              Master's                   1                      0
#
#    no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 0            14513         2007                 West         592.2029
# 1             2412         2002            Northeast       83425.6500
# 2            44444         2008                 West      122996.8600
# 3               98         1897                 West       83434.0300
# 4             1082         2005                South      149907.3900
#
#   unit_of_wage  full_time_position case_status
# ...

# %%
# Applying the one-hot encoding on the region_of_employment replacing West with 0,Northeast with 1,South with 2,Midwest with 3 and Island with 4
data['region_of_employment'] = data['region_of_employment'].map({'West':0,'Northeast':1,'South':2,'Midwest':3,'Island':4})

# %%
# Applying the one-hot encoding on the unit_of_wage replacing Hour with 0,Year with 1,Week  with 2,Month with 3 and Island with 4
data['unit_of_wage'] = data['unit_of_wage'].map({'Hour':0,'Year':1,'Week':2,'Month':3})

# %%
data.head()
# Out:
#    continent education_of_employee  has_job_experience  requires_job_training  \
# 0          0           High School                   0                      0
# 1          0              Master's                   1                      0
# 2          0            Bachelor's                   0                      1
# 3          0            Bachelor's                   0                      0
# 4          1              Master's                   1                      0
#
#    no_of_employees  yr_of_estab  region_of_employment  prevailing_wage  \
# 0            14513         2007                     0         592.2029
# 1             2412         2002                     1       83425.6500
# 2            44444         2008                     0      122996.8600
# 3               98         1897                     0       83434.0300
# 4             1082         2005                     2      149907.3900
#
#    unit_of_wage  full_time_position case_status
# ...

# %% [markdown]
# # Conclusions

# %%
# Data Profile:

# "...Two types of outputs are present: Certified and Denied, making it a classification problem."
# Univariate Analysis:

# "Most employees fall within the salary range of 0 to 100,000, and the distribution is right-skewed."
# "Most companies were established between the years 1950 and 2000, and the distribution is left-skewed."
# "The majority of employees have wages ranging from 25,000 to 1,750,000."

# Bivariate Analysis:

# "There is a positive correlation between the year of establishment and prevailing wage."
# "A higher year of establishment is associated with a larger number of employees."

# Categorical Analysis:

# Number of Employees vs. Continents:

# "Asia has the highest number of employees."
# "Oceania has the lowest number of employees."

# Number of Employees vs. Level of Education:

# "A higher number of employees hold Bachelor's degrees."
# "The fewest employees hold Doctorate degrees."

# Wages vs. Level of Education:

# "Bachelor's degree holders earn the highest wages."
# "Doctorate degree holders earn the lowest wages."

# Wages vs. Unit:

# "Employees working yearly earn higher wages compared to others."
# "Employees working monthly earn the lowest wages."

# Full-Time Positions:

# "Bachelor's degree holders make up the highest percentage of full-time employees at 41.94%."
# "Doctorate degree holders make up the lowest percentage of full-time employees at 9.27%."

# Not Full-Time Positions:

# "Master's degree holders make up the highest percentage of non-full-time employees at 64.20%."
# "Doctorate degree holders make up the lowest percentage of non-full-time employees at 2.96%."

# Continent which are accepted for the visas

# "Asia is one of the continents with the highest certification rate for visas."
# "Oceania is one of the continents with the lowest certification rate for visas."

# Continent which are denied for the visas

# "Asia is one of the continents with the highest rate of non-certification for visas."
# "Oceania is one of the continents with the highest rate of non-certification for visas."
