# %%
import pandas as pd
import numpy as np
import dtale
import sweetviz

# %%
df = pd.read_csv('Travel.csv')

# %%
df.head()
# Out:
#    CustomerID  ProdTaken   Age    TypeofContact  CityTier  DurationOfPitch  \
# 0      200000          1  41.0     Self Enquiry         3              6.0
# 1      200001          0  49.0  Company Invited         1             14.0
# 2      200002          1  37.0     Self Enquiry         1              8.0
# 3      200003          0  33.0  Company Invited         1              9.0
# 4      200004          0   NaN     Self Enquiry         1              8.0
#
#        Occupation  Gender  NumberOfPersonVisiting  NumberOfFollowups  \
# 0        Salaried  Female                       3                3.0
# 1        Salaried    Male                       3                4.0
# 2     Free Lancer    Male                       3                4.0
# 3        Salaried  Female                       2                3.0
# 4  Small Business    Male                       2                3.0
#
#   ProductPitched  PreferredPropertyStar MaritalStatus  NumberOfTrips  \
# ...

# %% [markdown]
# EDA using D-tale

# %%
d = dtale.show(df)
d.open_browser()
# Out:
# 2023-08-29 00:43:41,401 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,467 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,472 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,475 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,477 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,479 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,483 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,485 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,490 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,493 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,495 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2023-08-29 00:43:41,495 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...

# %% [markdown]
# EDA using SweetViz

# %%
df = pd.read_csv('Travel.csv')
analysis = sweetviz.analyze([df,'Travel'])
analysis.show_html('Report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
